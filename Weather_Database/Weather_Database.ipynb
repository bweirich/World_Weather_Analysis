# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create random sets of lat and long
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)
lat_lng = zip(lats, lngs)

# %%
# Create list of lat and long
coordinates = list(lat_lng)

# %%
# Get cities for each coordinate
cities = []
for coord in coordinates:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    
    # Add to cities list if not already there
    if city not in cities:
        cities.append(city)

# %%
# URLfor request
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

# %%
# collect weather info for cities
city_data = []

# initiate counter
record_count = 1

# loop through cities
for i, city in enumerate(cities):
    city_url = url + '&q=' + city.replace(" ", "+")
    
    print(f'Processing {record_count} | {city}')
    # request data for each city
    
    # Add to record count
    record_count += 1
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloudiness = city_weather['clouds']['all']
        city_wind_speed = city_weather['wind']['speed']
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        
        # Append to list
        city_data.append({
            'City': city.title(),
            'Country': city_country,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_cloudiness,
            'Wind Speed': city_wind_speed,
            'Current Description': city_description
        })
        
    # print error if not found
    except:
        print('City not found. Skipping....')
        pass
    
print('Complete')
# Out:
# Processing 1 | vaini
# Processing 2 | rikitea
# Processing 3 | puerto ayora
# Processing 4 | deputatskiy
# Processing 5 | ancud
# Processing 6 | montoro
# Processing 7 | bambous virieux
# Processing 8 | cosala
# Processing 9 | mataura
# Processing 10 | jalu
# Processing 11 | hilo
# Processing 12 | rairangpur
# Processing 13 | tiksi
# Processing 14 | tuktoyaktuk
# Processing 15 | bethel
# Processing 16 | ushuaia
# Processing 17 | buraydah
# Processing 18 | amderma
# City not found. Skipping....
# Processing 19 | alta floresta
# Processing 20 | alyangula
# Processing 21 | port alfred
# Processing 22 | kaitangata
# Processing 23 | busselton
# Processing 24 | sao filipe
# Processing 25 | taolanaro
# City not found. Skipping....
# Processing 26 | castro
# Processing 27 | magadan
# Processing 28 | hermanus
# Processing 29 | maldonado
# Processing 30 | aklavik
# Processing 31 | praia
# Processing 32 | lompoc
# Processing 33 | nizhneyansk
# City not found. Skipping....
# Processing 34 | naze
# Processing 35 | reconquista
# Processing 36 | batagay-alyta
# Processing 37 | kavieng
# Processing 38 | springbok
# Processing 39 | hokitika
# Processing 40 | amuntai
# Processing 41 | avarua
# Processing 42 | attawapiskat
# City not found. Skipping....
# Processing 43 | pochutla
# Processing 44 | salalah
# Processing 45 | samarai
# Processing 46 | cape town
# Processing 47 | beboto
# Processing 48 | lata
# Processing 49 | illoqqortoormiut
# City not found. Skipping....
# Processing 50 | sinjar
# Processing 51 | katsuura
# Processing 52 | mahebourg
# Processing 53 | albany
# Processing 54 | adjumani
# Processing 55 | dikson
# Processing 56 | riyadh
# Processing 57 | nioro
# Processing 58 | andros town
# Processing 59 | kaeo
# Processing 60 | mutsamudu
# City not found. Skipping....
# Processing 61 | saint george
# Processing 62 | saint-philippe
# Processing 63 | sorvag
# City not found. Skipping....
# Processing 64 | lavrentiya
# Processing 65 | abu dhabi
# Processing 66 | yining
# Processing 67 | brae
# Processing 68 | louisbourg
# City not found. Skipping....
# Processing 69 | los algarrobos
# Processing 70 | camacha
# Processing 71 | noumea
# Processing 72 | lydenburg
# Processing 73 | atuona
# Processing 74 | punta arenas
# Processing 75 | tasiilaq
# Processing 76 | provideniya
# Processing 77 | vila do maio
# Processing 78 | ulaanbaatar
# Processing 79 | medicine hat
# Processing 80 | clyde river
# Processing 81 | bathsheba
# Processing 82 | college
# Processing 83 | hobart
# Processing 84 | mezen
# Processing 85 | narsaq
# Processing 86 | eureka
# Processing 87 | georgetown
# Processing 88 | lumeje
# Processing 89 | camacupa
# Processing 90 | sentyabrskiy
# City not found. Skipping....
# Processing 91 | new norfolk
# Processing 92 | boyle
# Processing 93 | jamestown
# Processing 94 | marsh harbour
# Processing 95 | victoria
# Processing 96 | vaitupu
# City not found. Skipping....
# Processing 97 | hithadhoo
# Processing 98 | kingman
# Processing 99 | bluff
# Processing 100 | robertsport
# Processing 101 | mamallapuram
# Processing 102 | tilichiki
# Processing 103 | iqaluit
# Processing 104 | moroni
# Processing 105 | homer
# Processing 106 | qaanaaq
# Processing 107 | samana
# Processing 108 | mar del plata
# Processing 109 | san policarpo
# Processing 110 | fort dodge
# Processing 111 | coihaique
# Processing 112 | pevek
# Processing 113 | meyungs
# City not found. Skipping....
# Processing 114 | santiago del estero
# Processing 115 | alenquer
# Processing 116 | pitiquito
# Processing 117 | agadez
# Processing 118 | olafsvik
# Processing 119 | puerto colombia
# Processing 120 | kapaa
# Processing 121 | halifax
# Processing 122 | dauphin
# Processing 123 | quesnel
# Processing 124 | lagoa
# Processing 125 | saint anthony
# Processing 126 | ushumun
# Processing 127 | nangong
# Processing 128 | bredasdorp
# Processing 129 | cabedelo
# Processing 130 | oudtshoorn
# Processing 131 | carnarvon
# Processing 132 | saleaula
# City not found. Skipping....
# Processing 133 | arkhangelsk
# Processing 134 | kodiak
# Processing 135 | san jose de sisa
# Processing 136 | fuxin
# Processing 137 | lebyazhye
# Processing 138 | kalmunai
# Processing 139 | khonuu
# City not found. Skipping....
# Processing 140 | fortuna
# Processing 141 | vyartsilya
# Processing 142 | toliary
# City not found. Skipping....
# Processing 143 | butaritari
# Processing 144 | oiso
# Processing 145 | chernyshevskiy
# Processing 146 | korla
# Processing 147 | waipawa
# Processing 148 | eskasem
# City not found. Skipping....
# Processing 149 | thompson
# Processing 150 | adrar
# Processing 151 | morondava
# Processing 152 | raga
# Processing 153 | ankazoabo
# Processing 154 | lima
# Processing 155 | mys shmidta
# City not found. Skipping....
# Processing 156 | irbeyskoye
# Processing 157 | calvinia
# Processing 158 | barrow
# Processing 159 | denpasar
# Processing 160 | umzimvubu
# City not found. Skipping....
# Processing 161 | caxito
# Processing 162 | nikolskoye
# Processing 163 | marsa matruh
# Processing 164 | chokurdakh
# Processing 165 | coquimbo
# Processing 166 | najran
# Processing 167 | necochea
# Processing 168 | ahipara
# Processing 169 | uroteppa
# City not found. Skipping....
# Processing 170 | sakaiminato
# Processing 171 | port-gentil
# Processing 172 | gubkinskiy
# Processing 173 | zhigansk
# Processing 174 | cabo san lucas
# Processing 175 | ribeira grande
# Processing 176 | airai
# Processing 177 | aberystwyth
# Processing 178 | nantucket
# Processing 179 | marzuq
# Processing 180 | yellowknife
# Processing 181 | belushya guba
# City not found. Skipping....
# Processing 182 | brazzaville
# Processing 183 | bengkulu
# Processing 184 | benghazi
# Processing 185 | khatanga
# Processing 186 | kilindoni
# Processing 187 | kanniyakumari
# Processing 188 | honiara
# Processing 189 | kitimat
# Processing 190 | ardahan
# Processing 191 | tikrit
# Processing 192 | jiuquan
# Processing 193 | bytca
# Processing 194 | cidreira
# Processing 195 | kazalinsk
# City not found. Skipping....
# Processing 196 | fort-shevchenko
# Processing 197 | buala
# Processing 198 | chagda
# City not found. Skipping....
# Processing 199 | kidal
# Processing 200 | codrington
# Processing 201 | sao joao da barra
# Processing 202 | uruzgan
# Processing 203 | bakchar
# Processing 204 | mattawa
# Processing 205 | rungata
# City not found. Skipping....
# Processing 206 | russkiy aktash
# Processing 207 | hearst
# Processing 208 | kieta
# Processing 209 | nabire
# Processing 210 | ulladulla
# Processing 211 | cheuskiny
# City not found. Skipping....
# Processing 212 | kiama
# Processing 213 | lazaro cardenas
# Processing 214 | munsingen
# Processing 215 | liverpool
# Processing 216 | upington
# Processing 217 | keti bandar
# Processing 218 | harper
# Processing 219 | ruatoria
# City not found. Skipping....
# Processing 220 | grants
# Processing 221 | marcona
# City not found. Skipping....
# Processing 222 | port elizabeth
# Processing 223 | las palmas
# Processing 224 | talbahat
# Processing 225 | walvis bay
# Processing 226 | sisimiut
# Processing 227 | ciras
# City not found. Skipping....
# Processing 228 | mehamn
# Processing 229 | namatanai
# Processing 230 | kyra
# Processing 231 | shu
# Processing 232 | san carlos de bariloche
# Processing 233 | mahibadhoo
# Processing 234 | fort nelson
# Processing 235 | chicama
# Processing 236 | longlac
# City not found. Skipping....
# Processing 237 | kununurra
# Processing 238 | gushikawa
# Processing 239 | lebu
# Processing 240 | dong hoi
# Processing 241 | luderitz
# Processing 242 | vestmannaeyjar
# Processing 243 | norman wells
# Processing 244 | torbay
# Processing 245 | port hardy
# Processing 246 | barentsburg
# City not found. Skipping....
# Processing 247 | beloha
# Processing 248 | bogorodskoye
# Processing 249 | dunedin
# Processing 250 | westport
# Processing 251 | grand river south east
# City not found. Skipping....
# Processing 252 | suez
# Processing 253 | teya
# Processing 254 | port hedland
# Processing 255 | moussoro
# Processing 256 | kruisfontein
# Processing 257 | lorengau
# Processing 258 | leningradskiy
# Processing 259 | ayan
# Processing 260 | behshahr
# Processing 261 | kahului
# Processing 262 | samusu
# City not found. Skipping....
# Processing 263 | pisco
# Processing 264 | ardakan
# Processing 265 | faya
# Processing 266 | flinders
# Processing 267 | kalangala
# Processing 268 | puerto escondido
# Processing 269 | bonthe
# Processing 270 | havelock
# Processing 271 | cam pha
# City not found. Skipping....
# Processing 272 | carmelo
# Processing 273 | klaksvik
# Processing 274 | lolua
# City not found. Skipping....
# Processing 275 | waterloo
# Processing 276 | hervey bay
# Processing 277 | dhidhdhoo
# Processing 278 | ereymentau
# Processing 279 | juneau
# Processing 280 | valparaiso
# Processing 281 | zinder
# Processing 282 | nepomuceno
# Processing 283 | pavlivka
# Processing 284 | salta
# Processing 285 | dayong
# Processing 286 | nyurba
# Processing 287 | hasaki
# Processing 288 | evensk
# Processing 289 | monte alegre de minas
# Processing 290 | trzcianka
# Processing 291 | yeltsovka
# City not found. Skipping....
# Processing 292 | ballina
# Processing 293 | huambo
# Processing 294 | safwah
# City not found. Skipping....
# Processing 295 | ilulissat
# Processing 296 | abong mbang
# Processing 297 | souillac
# Processing 298 | los llanos de aridane
# Processing 299 | margate
# Processing 300 | nhulunbuy
# Processing 301 | shuangcheng
# Processing 302 | nara
# Processing 303 | jacareacanga
# Processing 304 | praia da vitoria
# Processing 305 | guarda
# Processing 306 | comodoro rivadavia
# Processing 307 | gamba
# Processing 308 | shirokiy
# Processing 309 | vanavara
# Processing 310 | imbituba
# Processing 311 | tchollire
# Processing 312 | atherton
# Processing 313 | huicungo
# Processing 314 | shreveport
# Processing 315 | alice springs
# Processing 316 | coahuayana
# Processing 317 | aleksandrovsk-sakhalinskiy
# Processing 318 | vysokopillya
# Processing 319 | pangnirtung
# Processing 320 | atar
# Processing 321 | taoudenni
# Processing 322 | saskylakh
# Processing 323 | meulaboh
# Processing 324 | oistins
# Processing 325 | susanville
# Processing 326 | lufilufi
# Processing 327 | komsomolskiy
# Processing 328 | okhotsk
# Processing 329 | coxim
# Processing 330 | usvyaty
# Processing 331 | channel-port aux basques
# Processing 332 | breves
# Processing 333 | chaman
# Processing 334 | llanes
# Processing 335 | nizhniy odes
# Processing 336 | maceio
# Processing 337 | mouzakion
# City not found. Skipping....
# Processing 338 | sivaki
# Processing 339 | faanui
# Processing 340 | caravelas
# Processing 341 | manicore
# Processing 342 | zvishavane
# Processing 343 | juegang
# Processing 344 | kiomboi
# Processing 345 | dutlwe
# Processing 346 | birao
# Processing 347 | constitucion
# Processing 348 | yar-sale
# Processing 349 | eyrarbakki
# Processing 350 | belyy yar
# Processing 351 | carutapera
# Processing 352 | mrirt
# City not found. Skipping....
# Processing 353 | mogadishu
# Processing 354 | kiunga
# Processing 355 | cherskiy
# Processing 356 | gunjur
# Processing 357 | tabiauea
# City not found. Skipping....
# Processing 358 | whitehorse
# Processing 359 | nanortalik
# Processing 360 | tsihombe
# City not found. Skipping....
# Processing 361 | dinghai
# Processing 362 | altamira
# Processing 363 | itarema
# Processing 364 | upernavik
# Processing 365 | ponta delgada
# Processing 366 | bulawayo
# Processing 367 | tuy hoa
# Processing 368 | weligama
# Processing 369 | savannakhet
# Processing 370 | fairbanks
# Processing 371 | sistranda
# Processing 372 | half moon bay
# Processing 373 | port lincoln
# Processing 374 | port blair
# Processing 375 | utiroa
# City not found. Skipping....
# Processing 376 | ponta do sol
# Processing 377 | wewak
# Processing 378 | talnakh
# Processing 379 | oussouye
# Processing 380 | tezu
# Processing 381 | bolsheustikinskoye
# City not found. Skipping....
# Processing 382 | marawi
# Processing 383 | thinadhoo
# Processing 384 | mao
# Processing 385 | visnes
# Processing 386 | east london
# Processing 387 | vardo
# Processing 388 | broome
# Processing 389 | vao
# Processing 390 | walker
# Processing 391 | aasiaat
# Processing 392 | waitati
# Processing 393 | nileshwar
# Processing 394 | oranjestad
# Processing 395 | rio grande
# Processing 396 | avera
# Processing 397 | cap malheureux
# Processing 398 | severo-kurilsk
# Processing 399 | ossora
# Processing 400 | isetskoye
# Processing 401 | hoquiam
# Processing 402 | tessalit
# Processing 403 | komnina
# Processing 404 | makakilo city
# Processing 405 | barkot
# Processing 406 | karaul
# City not found. Skipping....
# Processing 407 | montorio al vomano
# Processing 408 | beringovskiy
# Processing 409 | seagoville
# Processing 410 | hamilton
# Processing 411 | micomeseng
# Processing 412 | zyryanka
# Processing 413 | xai-xai
# Processing 414 | tashtyp
# Processing 415 | mahadday weyne
# City not found. Skipping....
# Processing 416 | longyearbyen
# Processing 417 | shitanjing
# Processing 418 | watertown
# Processing 419 | havoysund
# Processing 420 | bur gabo
# City not found. Skipping....
# Processing 421 | te anau
# Processing 422 | roura
# Processing 423 | faro
# Processing 424 | okato
# Processing 425 | yulara
# Processing 426 | alofi
# Processing 427 | melito di porto salvo
# Processing 428 | geraldton
# Processing 429 | kazachinskoye
# Processing 430 | kemijarvi
# Processing 431 | agaro
# Processing 432 | deloraine
# Processing 433 | mildura
# Processing 434 | mangrol
# Processing 435 | arraial do cabo
# Processing 436 | balabac
# Processing 437 | ambilobe
# Processing 438 | vila velha
# Processing 439 | meiktila
# Processing 440 | santa isabel do rio negro
# Processing 441 | tingrela
# City not found. Skipping....
# Processing 442 | bandarbeyla
# Processing 443 | imeni babushkina
# Processing 444 | san jeronimo
# Processing 445 | carauari
# Processing 446 | aswan
# Processing 447 | santa fe
# Processing 448 | kamenskoye
# City not found. Skipping....
# Processing 449 | qaqortoq
# Processing 450 | afogados da ingazeira
# Processing 451 | grindavik
# Processing 452 | baker city
# Processing 453 | iisalmi
# Processing 454 | poum
# Processing 455 | salinas
# Processing 456 | lokosovo
# Processing 457 | zhucheng
# Processing 458 | teguldet
# Processing 459 | san patricio
# Processing 460 | kirakira
# Processing 461 | filingue
# Processing 462 | kasungu
# Processing 463 | altoona
# Processing 464 | kashi
# Processing 465 | hihifo
# City not found. Skipping....
# Processing 466 | tramandai
# Processing 467 | la libertad
# Processing 468 | jiaonan
# Processing 469 | bondo
# Processing 470 | abu samrah
# Processing 471 | palmer
# Processing 472 | pandan
# Processing 473 | padang
# Processing 474 | strezhevoy
# Processing 475 | nanga eboko
# Processing 476 | kudahuvadhoo
# Processing 477 | leh
# Processing 478 | yumen
# Processing 479 | carman
# Processing 480 | inyonga
# Processing 481 | pocatello
# Processing 482 | haapiti
# Processing 483 | novikovo
# Processing 484 | paka
# Processing 485 | linden
# Processing 486 | isangel
# Processing 487 | chernyshevsk
# Processing 488 | esperance
# Processing 489 | san cristobal
# Processing 490 | kainantu
# Processing 491 | khani
# Processing 492 | constantine
# Processing 493 | kaduqli
# Processing 494 | roma
# Processing 495 | acapulco
# Processing 496 | yeehaw junction
# City not found. Skipping....
# Processing 497 | binzhou
# Processing 498 | skjervoy
# Processing 499 | dien bien
# City not found. Skipping....
# Processing 500 | galesong
# Processing 501 | huarmey
# Processing 502 | locri
# Processing 503 | manggar
# Processing 504 | sao gabriel da cachoeira
# Processing 505 | taquara
# Processing 506 | makokou
# Processing 507 | anadyr
# Processing 508 | pimentel
# Processing 509 | port macquarie
# Processing 510 | fukue
# Processing 511 | yongan
# Processing 512 | dudinka
# Processing 513 | scottsbluff
# Processing 514 | pelotas
# Processing 515 | warrnambool
# Processing 516 | antofagasta
# Processing 517 | kavaratti
# Processing 518 | kamenka
# Processing 519 | hinundayan
# Processing 520 | borzya
# Processing 521 | gonen
# Processing 522 | youghal
# Processing 523 | inirida
# Processing 524 | opuwo
# Processing 525 | asau
# Processing 526 | labuhan
# Processing 527 | saint-pierre
# Processing 528 | treinta y tres
# Processing 529 | bonanza
# Processing 530 | salur
# Processing 531 | sitka
# Processing 532 | lubao
# Processing 533 | saint-joseph
# Processing 534 | teeli
# Processing 535 | kisangani
# Processing 536 | ivanteyevka
# Processing 537 | gulshat
# City not found. Skipping....
# Processing 538 | hobyo
# Processing 539 | acarau
# Processing 540 | shaoguan
# Processing 541 | vanino
# Processing 542 | elizabeth city
# Processing 543 | tinskoy
# Processing 544 | mitzic
# Processing 545 | nome
# Processing 546 | traiguen
# Processing 547 | yorkton
# Processing 548 | mayo
# Processing 549 | alghero
# Processing 550 | touros
# Processing 551 | gayeri
# Processing 552 | ternate
# Processing 553 | jurm
# Processing 554 | miles city
# Processing 555 | cervia
# Processing 556 | tabuk
# Processing 557 | omboue
# Processing 558 | methoni
# Processing 559 | ola
# Processing 560 | henties bay
# Processing 561 | abu zabad
# Processing 562 | maudaha
# Processing 563 | ust-nera
# Processing 564 | warqla
# City not found. Skipping....
# Processing 565 | portland
# Processing 566 | kholtoson
# Processing 567 | pemangkat
# Processing 568 | banda aceh
# Processing 569 | leeton
# Processing 570 | strenci
# Processing 571 | huilong
# Processing 572 | guerrero negro
# Processing 573 | hodmezovasarhely
# Processing 574 | majene
# Processing 575 | miracatu
# Processing 576 | berdigestyakh
# Processing 577 | voh
# Processing 578 | tema
# Processing 579 | moron
# Processing 580 | fare
# Processing 581 | mackay
# Processing 582 | whyalla
# Processing 583 | prince george
# Processing 584 | omsukchan
# Processing 585 | hofn
# Processing 586 | kawalu
# Processing 587 | putignano
# Processing 588 | polignano a mare
# Processing 589 | palana
# Processing 590 | bowen
# Processing 591 | byron bay
# Processing 592 | west plains
# Processing 593 | berlevag
# Processing 594 | khon buri
# Processing 595 | southbridge
# Processing 596 | el alto
# Processing 597 | moindou
# Processing 598 | hovd
# Processing 599 | kutum
# Processing 600 | luwuk
# Processing 601 | betsiamites
# Processing 602 | boyolangu
# Processing 603 | lemesos
# City not found. Skipping....
# Processing 604 | hualmay
# Processing 605 | kiruna
# Processing 606 | flagstaff
# Processing 607 | roebourne
# Processing 608 | bijapur
# Processing 609 | buenaventura
# Processing 610 | key west
# Processing 611 | russell
# Processing 612 | kingston
# Processing 613 | mount gambier
# Processing 614 | yerbogachen
# Processing 615 | melfort
# Processing 616 | manyana
# Processing 617 | santa rosa
# Processing 618 | trujillo
# Processing 619 | whitianga
# Processing 620 | banmo
# City not found. Skipping....
# Processing 621 | den helder
# Processing 622 | gurh
# Processing 623 | el tocuyo
# Processing 624 | tuatapere
# Processing 625 | yeniseysk
# Processing 626 | saldanha
# Processing 627 | namibe
# Processing 628 | sete
# Processing 629 | tiznit
# Processing 630 | johi
# Processing 631 | vila
# Processing 632 | ilebo
# Processing 633 | pokhara
# Processing 634 | erzin
# Processing 635 | khorramabad
# Processing 636 | saint-augustin
# Processing 637 | northam
# Processing 638 | pergamino
# Processing 639 | camana
# Processing 640 | samalaeulu
# City not found. Skipping....
# Processing 641 | chumikan
# Processing 642 | opobo
# City not found. Skipping....
# Processing 643 | calabozo
# Processing 644 | la ronge
# Processing 645 | viedma
# Processing 646 | tomislavgrad
# Processing 647 | barcs
# Processing 648 | menongue
# Processing 649 | witu
# Processing 650 | kargil
# Processing 651 | sola
# Processing 652 | panzhihua
# Processing 653 | yalvac
# Processing 654 | dori
# Processing 655 | chapleau
# Processing 656 | altay
# Processing 657 | qeshm
# Processing 658 | bor
# Processing 659 | soavinandriana
# Processing 660 | alugan
# Processing 661 | rawson
# Processing 662 | ust-ishim
# Processing 663 | balakhta
# Processing 664 | felidhoo
# City not found. Skipping....
# Processing 665 | fort saint john
# City not found. Skipping....
# Processing 666 | haibowan
# City not found. Skipping....
# Processing 667 | bichena
# Processing 668 | jacmel
# Processing 669 | ngunguru
# Processing 670 | sechura
# Processing 671 | olinda
# Processing 672 | aleksandrov gay
# Processing 673 | grand gaube
# Processing 674 | ronchi dei legionari
# Processing 675 | cotonou
# Processing 676 | biak
# Processing 677 | kaseda
# Processing 678 | cairns
# Processing 679 | boueni
# Processing 680 | yerofey pavlovich
# Processing 681 | broken hill
# Processing 682 | bolungarvik
# City not found. Skipping....
# Processing 683 | mangai
# Processing 684 | juifang
# City not found. Skipping....
# Processing 685 | karauzyak
# City not found. Skipping....
# Processing 686 | antalaha
# Processing 687 | davila
# Processing 688 | ikalamavony
# Processing 689 | myitkyina
# Processing 690 | kumphawapi
# Processing 691 | pyaozerskiy
# Processing 692 | kurinjippadi
# Processing 693 | wahran
# City not found. Skipping....
# Processing 694 | resistencia
# Processing 695 | taboshar
# Processing 696 | gopalpur
# Processing 697 | shaoyang
# Processing 698 | palabuhanratu
# City not found. Skipping....
# Processing 699 | brovst
# Processing 700 | melfi
# Processing 701 | karratha
# Processing 702 | burns lake
# Processing 703 | sinnai
# Processing 704 | montepuez
# Processing 705 | christchurch
# Processing 706 | mangaratiba
# Processing 707 | ostrovnoy
# Processing 708 | tumannyy
# City not found. Skipping....
# Processing 709 | rabat
# Processing 710 | koutselion
# Processing 711 | savannah bight
# Processing 712 | eyl
# Processing 713 | vostok
# Processing 714 | egvekinot
# Processing 715 | villa rica
# Processing 716 | baltiysk
# Processing 717 | bosaso
# Processing 718 | kushiro
# Processing 719 | auki
# Processing 720 | launceston
# Processing 721 | buctzotz
# Processing 722 | dingle
# Processing 723 | kahta
# Processing 724 | devrek
# Processing 725 | voyvozh
# Processing 726 | gangotri
# City not found. Skipping....
# Processing 727 | camabatela
# Processing 728 | tottori
# Processing 729 | baiyin
# Processing 730 | beitbridge
# Processing 731 | richards bay
# Processing 732 | husavik
# Processing 733 | canyon lake
# Processing 734 | tura
# Processing 735 | srednekolymsk
# Processing 736 | verkhnyaya sinyachikha
# Processing 737 | pacific grove
# Processing 738 | turukhansk
# Processing 739 | pundaguitan
# Processing 740 | hua hin
# Processing 741 | ulaangom
# Processing 742 | hay river
# Processing 743 | soyo
# Processing 744 | tunduru
# City not found. Skipping....
# Processing 745 | sinop
# Processing 746 | wladyslawowo
# Processing 747 | prachuap khiri khan
# Processing 748 | awjilah
# Processing 749 | syracuse
# Processing 750 | lixourion
# Processing 751 | kuching
# Processing 752 | roshchino
# Processing 753 | misratah
# Processing 754 | wilmington
# Processing 755 | quatre cocos
# Processing 756 | koumac
# Processing 757 | soledad
# Processing 758 | phan thiet
# Processing 759 | santo amaro
# Processing 760 | bodden town
# Processing 761 | milos
# Processing 762 | cocachacra
# Processing 763 | ndioum
# Processing 764 | passagem franca
# Processing 765 | chuy
# Processing 766 | raglan
# Complete

# %%
# Create DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Vaini      TO -21.2000 -175.2000     80.60        69          20
# 1          Rikitea      PF -23.1203 -134.9692     77.25        60           0
# 2     Puerto Ayora      EC  -0.7393  -90.3518     77.00        92          16
# 3      Deputatskiy      RU  69.3000  139.9000     -1.57        90          82
# 4            Ancud      CL -41.8697  -73.8203     54.00        88         100
# 5          Montoro      ES  38.0241   -4.3834     60.80        72           0
# 6  Bambous Virieux      MU -20.3428   57.7575     80.01        88          75
# 7           Cosala      MX  24.4125 -106.6908     72.00        83          22
# 8          Mataura      NZ -46.1927  168.8643     64.99        60          11
# 9             Jalu      LY  29.0331   21.5482     62.62        32          14
#
#    Wind Speed Current Description
# 0        9.22          few clouds
# 1        7.65           clear sky
# 2        1.01          few clouds
# 3        2.89       broken clouds
# 4       11.01     overcast clouds
# 5        3.44           clear sky
# 6        9.22          light rain
# 7        3.00          few clouds
# 8        3.00          few clouds
# 9        8.61          few clouds

# %%
# Create output file
output_file = 'WeatherPy_Database.csv'
# Save file
city_data_df.to_csv(output_file, index_label='City_ID')
